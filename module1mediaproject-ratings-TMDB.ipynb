# %% [markdown]
# ## Final Project Submission

# %%
# Your code here - remember to use markdown cells for comments as well!
import requests
import json

# %%
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=27707de056fdcbfbabf1bca5b0bc4c6d&primary_release_year=2000&sort_by=vote_average.desc')

# %%
print(response.status_code) #status code 200 means "Everything went okay, and the result has been returned (if any)."
# Out:
# 200

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "page": 1,
#     "results": [
#         {
#             "adult": false,
#             "backdrop_path": "/fdmFjyty995vtpjUx34taB9s1y7.jpg",
#             "genre_ids": [],
#             "id": 120392,
#             "original_language": "en",
#             "original_title": "Britney Spears: Oops!... I Did It Again Tour 2000",
#             "overview": "Britney's first world tour came in 2000 in support of her second album Oops ! ... I did it again and featuring pryo, props and movable platforms. The show commenced with Britney arriving in a giant metal orb, moving into her bedroom, performing on a staircase, in a giant kimono, at school in a cheerleader costume and ending with a tunnel of fire.",
#             "popularity": 1.255,
#             "poster_path": "/xJCxodmg0Yjqhw68uJ4CdDp5TCG.jpg",
#             "release_date": "2000-10-10",
#             "title": "Britney Spears: Oops!... I Did It Again Tour 2000",
#             "video": false,
#             "vote_average": 10,
# ...
